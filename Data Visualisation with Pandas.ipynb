# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#pyhton -m ensure pip

# %%
from numpy.random import randn, randint

# %%
pd.DataFrame(randn(1000))
# Out:
#             0
# 0   -0.949050
# 1   -0.778507
# 2   -0.851748
# 3    0.321125
# 4   -0.513557
# ..        ...
# 995  0.315917
# 996  0.763799
# 997 -0.253471
# 998 -0.653442
# 999  2.236715
#
# [1000 rows x 1 columns]

# %%
df = pd.DataFrame(randn(1000), 
                  index = pd.date_range('2023-12-01', 
                                        periods = 1000), 
                  columns=['value'])

df.head()
# Out:
#                value
# 2023-12-01  0.160221
# 2023-12-02 -0.809948
# 2023-12-03  0.034936
# 2023-12-04 -0.935915
# 2023-12-05 -1.465982

# %%
ts = pd.Series(randn(1000), 
               index = pd.date_range('2023-12-01', 
                                     periods = 1000))
ts.head()
# Out:
# 2023-12-01   -0.259042
# 2023-12-02    0.826909
# 2023-12-03   -1.238221
# 2023-12-04    0.729474
# 2023-12-05    0.918946
# Freq: D, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#                value
# 2023-12-01  0.160221
# 2023-12-02 -0.809948
# 2023-12-03  0.034936
# 2023-12-04 -0.935915
# 2023-12-05 -1.465982

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2023-12-01  0.160221
# 2023-12-02 -0.489506
# 2023-12-03 -1.104297
# 2023-12-04 -2.655003
# 2023-12-05 -5.671691

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2023-12-01   -0.259042
# 2023-12-02    0.567867
# 2023-12-03   -0.670354
# 2023-12-04    0.059120
# 2023-12-05    0.978065
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts.plot(figsize=(50,10))
# Out:
# <AxesSubplot:>

# %%
# Creating a plot for ts Series using matplotlib

plt.plot(ts)

# %%
plt.plot(df)

# %%
ts.plot(kind = 'bar', figsize = (15,5))
# Out:
# <AxesSubplot:>

# %%
# Horizontal bar graph
ts.plot(kind = 'barh', figsize = (20,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## IRIS dataset

# %%
iris = sns.load_dataset('iris')
#iris = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
# which feature has more variation
# range of features

# %%
_ = iris.plot(figsize=(15,8), title='Iris Dataset')
_.set_xlabel('X Axis')
_.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal.length    5.1
# sepal.width     3.5
# petal.length    1.4
# petal.width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar', xlabel = 'parameters', ylabel = 'values')
# Out:
# <AxesSubplot:xlabel='parameters', ylabel='values'>

# %%
df.iloc[0].plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_length'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
iris['sepal_length'].plot.hist(color = '#B5C71D',edgecolor = '#C73B1D')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', edgecolor = 'black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', edgecolor = 'black', stacked = False)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', edgecolor = 'black', stacked = True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = False, bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
_ = df.hist(color = 'b', alpha = 0.1, figsize=(10,10))
# df.hist() gives graphs in different windows

# %%
# df.plot() gives all the graphs in the same window
iris.plot(color = 'r', figsize = (10,10), kind = 'hist', alpha = 0.1)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Question:
#
# - 1. Plot a graph for fare price variation in titanic
# - 2. Survived in histogram

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length')
# after approximately (5, 3) the points seem to follow a pattern
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x = 'sepal.length', y = 'petal.length', label = 'Length');
# no pattern found
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
iris.plot.scatter(x = 'sepal.width', y = 'petal.width', label = 'Width', color = 'r')
# Out:
# <AxesSubplot:xlabel='sepal.width', ylabel='petal.width'>

# %%
iris.plot.scatter(x = 'sepal.width', y = 'petal.length', label = 'Width', color = 'g')
# Out:
# <AxesSubplot:xlabel='sepal.width', ylabel='petal.length'>

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 120)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris_2 = iris.drop(['species'], axis = 1)

# %%
d = iris_2.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie( figsize = (5,5))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
d2 = iris_2.head(3)
d2
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
d2.plot.pie(subplots = True, figsize = (20,20))
# Out:
# array([<AxesSubplot:ylabel='sepal_length'>,
#        <AxesSubplot:ylabel='sepal_width'>,
#        <AxesSubplot:ylabel='petal_length'>,
#        <AxesSubplot:ylabel='petal_width'>], dtype=object)

# %%
d = iris_2.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), autopct = '%.4f%%')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
plt.savefig('iris_pie.png')

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(iris_2, figsize= (8,8), color = 'b')
plt.show()

# %%
scatter_matrix(iris_2, figsize = (5,5), color ='r', diagonal='kde') #shows distribution of data
plt.show()

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)
# Out:
# <AxesSubplot:>

# %%
iris_2.plot(legend = True, figsize = (10, 5))
# Out:
# <AxesSubplot:>

# %%
iris_2.plot(subplots = True, legend = True, figsize = (10, 5))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
x.plot()

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
y.plot()

# %%
a2 = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = a2)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
iris.plot(subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
iris.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
# layout -> 2 rows 3 cols
