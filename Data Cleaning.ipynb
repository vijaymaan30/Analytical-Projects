# %% [markdown]
# # Assignment 1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 'Budapest_PaRis', 'Brussels_londOn'],
                    'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
                    'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                    'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )','12. Air France', '"Swiss Air"']})
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
#Some values in the the FlightNumber column are missing. These numbers are meant to increase by 10 with each row so 10055 and 10075 need to be put in place. Fill in these missing numbers and make the column an integer column (instead of a float column)
df['FlightNumber'] = df['FlightNumber'].fillna(method='ffill')+10
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10055.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10075.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10095.0      [67, 32]          "Swiss Air"

# %%
#The From_To column would be better as two separate columns! Split each string on the underscore delimiter _ to give a new temporary DataFrame with the correct values. Assign the correct column names to this temporary DataFrame

# %%
df2 = df['From_To'].str.split('_', expand=True)
df2.columns=['From','To']
df=df.join(df2)

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10055.0      [23, 47]               KLM(!)  \
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10075.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10095.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
#Standardise the strings so that only the first letter is uppercase (e.g. "londON" should become "London".)

# %%
df['From']=df['From'].str.title()
df['To']=df['To'].str.title()
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10055.0      [23, 47]               KLM(!)  \
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10075.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10095.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
df['Airline']=df['Airline'].str.title()
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10055.0      [23, 47]               Klm(!)  \
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10075.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10095.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
#Delete the From_To column from df and attach the temporary DataFrame from the previous questions

# %%
df.drop(['From_To'],axis=1)
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0       10055.0      [23, 47]               Klm(!)    London      Paris
# 1       10055.0            []    <Air France> (12)    Madrid      Milan
# 2       10075.0  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3       10075.0          [13]       12. Air France  Budapest      Paris
# 4       10095.0      [67, 32]          "Swiss Air"  Brussels     London

# %%
#In the RecentDelays column, the values have been entered into the DataFrame as a list.
#We would like each first value in its own column, each second value in its own column, and so on.
#If there isn't an Nth value, the value should be NaN.
#Expand the Series of lists into a DataFrame named delays, rename the columns delay_1, delay_2, etc. 
#and replace the unwanted RecentDelays column in df with delays

# %% [markdown]
# # Assignment 2

# %%
df3=pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')
df3
# Out:
#       order_id  quantity                              item_name
# 0            1         1           Chips and Fresh Tomato Salsa  \
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#Print total number of records
df3.shape
# Out:
# (4622, 5)

# %%
#Which was the most ordered item
df3.iloc[np.where(df3['quantity']==max(df3['quantity']))]
# Out:
#       order_id  quantity                     item_name choice_description
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN  \
#
#      item_price
# 3598    $44.25

# %%
df3.iloc[np.where(df3.quantity==max(df3.quantity))]
# Out:
#       order_id  quantity                     item_name choice_description
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN  \
#
#      item_price
# 3598    $44.25

# %%
#How many items were ordered?
df3.iloc[np.where(df3.item_name=='Chips and Fresh Tomato Salsa')]
# Out:
#       order_id  quantity                     item_name choice_description
# 0            1         1  Chips and Fresh Tomato Salsa                NaN  \
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 89          39         1  Chips and Fresh Tomato Salsa                NaN
# 183         82         1  Chips and Fresh Tomato Salsa                NaN
# ...        ...       ...                           ...                ...
# 4231      1689         1  Chips and Fresh Tomato Salsa                NaN
# 4318      1722         1  Chips and Fresh Tomato Salsa                NaN
# 4324      1725         1  Chips and Fresh Tomato Salsa                NaN
# 4425      1764         1  Chips and Fresh Tomato Salsa                NaN
# 4503      1790         1  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 0        $2.39
# 25       $2.39
# 55       $2.39
# ...

# %%
#Turn the item price into float type
df3.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df3['item_price'] = df3['item_price'].replace('[\$,]', '', regex=True).astype(float)

# %%
df3['item_price'].dtypes
# Out:
# dtype('float64')

# %%
#How much was the revenue for the period in the dataset?

# %%
#Print another data frame with only two columns item_name and item_price
df4=df3[['item_name','item_price']]
df4
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
#Delete the duplicates in item_name and quantity
df3.drop_duplicates(['item_name', 'quantity'])
# Out:
#       order_id  quantity                              item_name
# 0            1         1           Chips and Fresh Tomato Salsa  \
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 3890      1559         2                  Carnitas Crispy Tacos
# 3973      1592         4                      Canned Soft Drink
# 4152      1660        10                          Bottled Water
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df3
# Out:
#       order_id  quantity                              item_name
# 0            1         1           Chips and Fresh Tomato Salsa  \
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#select only the products with quantity equals to 1
df3.iloc[np.where(df3.quantity==1)]
# Out:
#       order_id  quantity                              item_name
# 0            1         1           Chips and Fresh Tomato Salsa  \
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#select only the item_name and item_price columns
df3[['item_name','item_price']]
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
#select only the item_name and item_price columns
df3.sort_values(by='item_price',ascending=False)
df3
# Out:
#       order_id  quantity                              item_name
# 0            1         1           Chips and Fresh Tomato Salsa  \
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
#What was the quantity of the most expensive item ordered?
df3.iloc[np.where(df3.item_price==max(df3.item_price))]
# Out:
#       order_id  quantity                     item_name choice_description
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN  \
#
#       item_price
# 3598       44.25

# %%
#How many times were a Veggie Salad Bowl ordered?
df3.iloc[np.where(df3.item_name=='Veggie Salad Bowl')]
# Out:
#       order_id  quantity          item_name
# 186         83         1  Veggie Salad Bowl  \
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# ...

# %%
len('Veggie Salad Bowl')
# Out:
# 17

# %% [markdown]
# # Assignment 3

# %%
ds=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')
ds
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape
# 0   1960   179323175   3384200   288460   3095700    9110          17190  \
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
#Convert the type of the column Year to datetime64

# %%
#Set the Year column as the index of the dataframe
ds.set_index('Year', inplace=True)
ds
# Out:
#       Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery
# Year
# 1960   179323175   3384200   288460   3095700    9110          17190   107840  \
# 1961   182992000   3488000   289390   3198600    8740          17220   106670
# 1962   185771000   3752200   301510   3450700    8530          17550   110860
# 1963   188483000   4109500   316970   3792500    8640          17650   116470
# 1964   191141000   4564600   364220   4200400    9360          21420   130390
# 1965   193526000   4739400   387390   4352000    9960          23410   138690
# 1966   195576000   5223500   430180   4793300   11040          25820   157990
# 1967   197457000   5903400   499930   5403500   12240          27620   202910
# 1968   199399000   6720200   595010   6125200   13800          31670   262840
# 1969   201385000   7410900   661870   6749000   14760          37170   298850
# 1970   203235298   8098000   738820   7359200   16000          37990   349860
# ...

# %%
#Group the year by decades and sum the values

# %%
#Select just the 'Murder' and 'Robbery' columns from the DataFrame df and print
print(ds['Murder'and'Robbery'])
# Out:
# Year
# 1960    107840
# 1961    106670
# 1962    110860
# 1963    116470
# 1964    130390
# 1965    138690
# 1966    157990
# 1967    202910
# 1968    262840
# 1969    298850
# 1970    349860
# 1971    387700
# 1972    376290
# 1973    384220
# 1974    442400
# 1975    470500
# 1976    427810
# 1977    412610
# 1978    426930
# 1979    480700
# 1980    565840
# 1981    592910
# 1982    553130
# 1983    506570
# 1984    485010
# 1985    497870
# 1986    542775
# 1987    517704
# 1988    542970
# 1989    578330
# 1990    639270
# 1991    687730
# 1992    672480
# 1993    659870
# 1994    618950
# 1995    580510
# 1996    535590
# 1997    498534
# 1998    446625
# 1999    409371
# 2000    408016
# 2001    423557
# 2002    420806
# 2003    414235
# 2004    401470
# 2005    417438
# 2006    447403
# 2007    445125
# 2008    443574
# 2009    408742
# 2010    369089
# 2011    354772
# 2012    355051
# 2013    345095
# 2014    325802
# Name: Robbery, dtype: int64

# %%
#Select the data in rows 3, 4, 8 and in columns 'Murder', 'Robbery'
ds.iloc[[3,4,8],4]
# Out:
# Year
# 1963     8640
# 1964     9360
# 1968    13800
# Name: Murder, dtype: int64

# %%
ds.iloc[[3,4,8],6]
# Out:
# Year
# 1963    116470
# 1964    130390
# 1968    262840
# Name: Robbery, dtype: int64

# %%
ds.loc[['1963','1964','1968'],['Murder','Robbery']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 ds.loc[['1963','1964','1968'],['Murder','Robbery']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1287, in _LocIndexer._getitem_tuple(self, tup)
#    1285 # ugly hack for GH #836
#    1286 if self._multi_take_opportunity(tup):
# -> 1287     return self._multi_take(tup)
#    1289 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
#Select only the rows where the number of murder is greater than 24,000
ds.iloc[np.where(ds['Murder']>24000)[0]]
# Out:
#       Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery
# Year
# 1991   252177000  14872900  1911770  12961100   24700         106590   687730  \
# 1993   257908000  14144800  1926020  12218800   24530         106010   659870
#
#       Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 